# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
img_set = np.load('original.npy')
plt.imshow(img_set[0].reshape(64, 64, 3))

# %%
img_set = np.load('noisy.npy')
plt.imshow(img_set[0].reshape(64, 64, 3))

# %%
img_set = np.load('recovered.npy')
plt.imshow(img_set[0].reshape(64, 64, 3))
