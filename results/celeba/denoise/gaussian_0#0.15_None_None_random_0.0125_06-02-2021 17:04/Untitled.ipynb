# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
noise = np.load('noise.npy')
noisy = np.load('noisy.npy')
original = np.load('original.npy')
recovered = np.load('recovered.npy')

# %%
plt.imshow(np.clip(original[0] + noise[0], 0, 1))

# %%
plt.imshow(noisy[0])

# %%
plt.imshow(recovered[0])
